# %%
import matplotlib.pyplot as plt

# %%
# line chart

# %%
ls = [41,52,65,60]
ls2 = [25,63,45,75]
plt.plot(ls,ls2)
plt.xlabel("LS-1")
plt.ylabel("LS-2")
# Out:
# Text(0, 0.5, 'LS-2')

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\ay998\\OneDrive\\Desktop\\15 july\\Used_Bikes.csv")
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
ls1 = [25,32,68,24,61]
ls2 = [96,45,12,36,45]
plt.scatter(x=ls1,y=ls2,marker='o',s=500,color='red')
plt.ylabel('List - 2 ')
plt.xlabel("List - 1 ")
plt.title("scatter plot ")
plt.show()

# %%
ls1 = [25,32,68,24,61]
ls2 = [96,45,12,36,45]
plt.scatter(x=ls1,y=ls2,marker='*',s=500,color='black')
plt.ylabel('List - 2 ')
plt.xlabel("List - 1 ")
plt.title("scatter plot ")
plt.show()

# %%
df.drop_duplicates(inplace=True)

# %%
plt.scatter(x=df['kms_driven'],y=df['price'])
plt.xlabel('Kms drivens')
plt.ylabel("Price")
plt.show()

# %%
import numpy as np
arr1 = np.random.randint(1,200,500)

# %%
arr2 = arr1*50

# %%
arr2 = arr1*50

# %%
plt.scatter(arr1,arr2)
plt.xlabel('arr - 1')
plt.ylabel("arr - 2")
plt.show()

# %%
# histogram
age =  np.random.randint(1,100,1000)
age
# Out:
# array([84, 52, 90, 40, 42, 13, 84, 88, 20, 29, 51, 41, 24, 37, 85, 34, 23,
#        94, 44, 40, 98, 67, 83, 90, 88, 31, 28, 36, 18, 79, 78, 20, 93, 27,
#        56, 73, 82, 19, 73, 91, 26, 20,  3, 56, 91, 58, 81, 27, 46, 15, 30,
#        11, 80, 70, 15, 34, 41,  2, 19, 48, 62, 19, 67, 90, 29, 74, 49, 39,
#        97, 76, 29, 59, 32, 99, 77, 63, 89, 82, 84, 13, 68, 74, 20, 49,  3,
#         4, 31, 97, 71, 72, 58,  8, 11, 43, 21, 16,  3, 38, 93, 49, 41, 34,
#        66, 73, 43, 95, 61, 34, 36, 37, 35, 28, 44,  6, 86, 30, 39,  1, 37,
#        93, 68, 21, 66, 83, 10, 39, 11, 74, 95, 29, 23, 54, 91, 61, 52, 73,
#        77, 94, 29, 94, 81, 43, 47, 33, 11, 29, 62, 27, 98, 49, 15,  5, 19,
#        91, 84, 34, 68, 50, 42, 50, 19,  5, 45, 50, 76, 26, 68, 98, 79,  1,
#        15, 33, 75, 25, 58, 95, 40, 63, 19, 67, 64, 89, 50,  4, 97, 35, 96,
#        17,  3, 29, 94, 59,  4, 78,  6, 90, 30, 69, 96, 27, 32, 75, 51, 87,
# ...

# %%
bucket = [0,18,30,50,70,90,110]
plt.hist(age,bins=bucket,ec='k')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bucket = [0,18,30,50,70,90,110]
plt.hist(age,ec='k',color='green')
plt.show()

# %%
df['price'].min()
# Out:
# np.float64(4400.0)

# %%
df['price'].max()
# Out:
# np.float64(1900000.0)

# %%
bucket = [25000,50000,75000,100000,125000,150000,175000,200000]
plt.hist(df['price'] , bins=bucket, ec="k")
# plt.xticks([0,18,30,50,70,90,110])
plt.xticks([25000,50000,75000,100000,125000,150000,175000,200000])
plt.show()

# %%
plt.boxplot(age)
plt.show()

# %%
plt.boxplot(df[df['brand']=="Bajaj"]['price'])
plt.show()

# %%
df[df['brand']=="Bajaj"]['price'].max()
# Out:
# np.float64(195000.0)
